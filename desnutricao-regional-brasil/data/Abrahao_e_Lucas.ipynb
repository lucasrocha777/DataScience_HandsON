# %% [markdown]
# ***
# # <font color=green size=10>**1ª ENTREGA DO PROJETO DATA SCIENCE APLICADO À SAÚDE**</font>
# ***
#
# **>> Nome completo dos integrantes da equipe**
#
# *Abrahão Picanço Neres de Oliveira e Lucas Gabriel Rocha Constancio*
#
#
# **>> Tema do projeto**
#
# *DIFERENÇAS REGIONAIS NA PREVALÊNCIA DA DESNUTRIÇÃO INFANTIL NO BRASIL*
#
#
# **>> Banco de dados consultado**
#
# *Estudo Nacional de Alimentação e Nutrição Infantil: ENANI-2019.*
#
# *Link: https://opendatasus.saude.gov.br/dataset/estudo-nacional-de-alimentacao-e-nutricao-infantil-enani-2019*
#
#
# **>> Banco de dados utilizado**
#
# *Pasta com todos os arquivos usados para o projeto:*
#
# *LINK: https://drive.google.com/drive/folders/1ZVu1o93VkY18xAumfjnTbRtxPycu_g0Q?usp=sharing*

# %% [markdown]
# ## <font color=green size=6>**Desenvolvimento do projeto**</font>
#
# **>> Problema a ser solucionado**
#
# *Objetivo analisar as diferenças regionais na prevalência da desnutrição infantil no Brasil, identificando os determinantes socioeconômicos que influenciam essas disparidades. A pesquisa investigará como fatores como a ocupação dos pais, tipo de domicílio e acesso a alimentos adequados impactam o estado nutricional das crianças. Além disso, será analisada a relação entre as condições de infraestrutura dos domicílios, como acesso a cozinhas e o tipo de habitação, e a prevalência de desnutrição. O intuito é fornecer informações para a formulação de políticas públicas eficazes, visando reduzir as desigualdades regionais e melhorar a nutrição infantil no país.*

# %% [markdown]
# ### **01. Importação de bibliotecas necessárias para o projeto.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### **02. Importação do banco de dados original.**

# %% [markdown]
# Devido ao fato de o dataset apresentar mais de 14 mil linhas, torna-se inviável exibir a tabela completa diretamente aqui.

# %%
with open('/content/[1] Dataset_Original.csv', 'r') as file:
    lines = file.readlines()

for i, line in enumerate(lines[:20]):  # Analise as 20 primeiras linhas
    print(f"Linha {i+1}: {line}")
# Out:
# Linha 1: "a00_regiao";"a06_domicilio";"a11_situacao";"b00_numero";"b02_sexo";"b03_relacao";"b04_idade";"b05_data";"b05a_idade_em_meses";"b06_numero_mae";"b06a_porque";"b06b_mae_responsavel";"bb04_idade_da_mae";"bbb08_numero_mais_novo1";"bbb08a_numero_mais_velho1";"d01_cor";"d02_matriculado";"d03_duracao";"d04_refeicao";"d05_quais_refeicoes";"d05a_refeicao_outra";"d06_relacao_responsavel";"d06a_qual_outra";"datablb";"datahorapedido";"datahorapedido_r";"e01_leite_peito";"e02_agua";"e03_filtrada_fervida";"e04_agua_com_acucar";"e05_cha";"e06_leite_vaca_po";"e07_leite_vaca_liquido";"e08_leite_soja_po";"e09_leite_soja_liquido";"e10_formula_infantil";"e11_suco";"e12_fruta_inteira";"e13_fruta_vezes";"e14_manga";"e16_comida_sal";"e17_sal_vezes";"e18_oferecida";"e181_pedacos";"e182_amassada";"e183_peneira";"e184_liquidificada";"e185_caldo";"e189_nao_sabe";"e19_mingau";"e20_iogurte";"e21_arroz";"e211a_pao_frances";"e212a_feito_em_casa";"e213a_industrializado";"e214a_nao_comeu";"e219a_nao_sabe";"e21a_pao";"e22_legumes";"e23_cenoura";"e24_couve";"e25_verduras";"e26_feijao";"e27_carne";"e28_figado";"e29_ovo";"e30_hamburger";"e31_salgadinhos";"e32_suco_industrializado";"e33_refrigerante";"e34_macarrao";"e35_biscoito";"e36_bala";"e37_tempero";"e38_farinhas";"e39_mamadeira";"e40_adocado";"estrato_sel_anon";"f001_esta_usando";"g001_usou";"g150_vitaminas";"g151_sache";"grupo10";"grupo11";"grupo12";"grupo13";"grupo14";"grupo15";"grupo16";"grupo17";"grupo18";"grupo19";"grupo1a";"grupo1b";"grupo1c";"grupo2";"grupo20";"grupo21";"grupo22";"grupo3";"grupo4";"grupo5";"grupo6";"grupo7";"grupo8";"grupo9a";"grupo9b";"h01_semanas_gravidez";"h02_peso";"h03_altura";"h04_parto";"h05_chupeta_usou";"h06_chupeta_comecou";"h07_chupeta_medida1";"h08_chupeta_parou";"h09_chupeta_medida2";"h10_consulta";"h10a_consulta_outro";"h10b_sindrome_de_down";"h10b1_sindrome_nao";"h10b2_sindrome_down";"h10b3_sindrome_fibrose";"h10b4_sindrome_fenilcetonuria";"h10b5_sindrome_autismo";"h10b9_sindrome_nao_sabe";"h11_alergia";"h12_alergias";"h121_alergia_leite";"h122_alergia_ovos";"h123_alergia_peixes";"h124_alergia_sementes";"h125_alergia_trigo";"h126_alergia_frutas";"h127_alergia_feijoes";"h128_alergia_outro";"h129_alergia_nao_sabe";"h12a_alergia_outro";"h13_diarreia";"h14_tosse";"h15_respiracao";"h16_canseira";"h17_nariz";"h18_ronqueira";"h19_febre";"h20_outro_problema";"h20a_problema_outro";"h21_internado";"h211_internado_respiratoria";"h212_internado_intestinais";"h213_internado_acidente";"h214_internado_alergias";"h215_internado_outras";"h216_internado_nao";"h219_internado_nao_sabe";"h21a_doenca_outra";"i000_2m_faz";"i000b_data_do_dia";"i000c_idade_em_meses";"i000d_data_ajustada";"i000e_semanas_gravidez";"i001_2m_feliz";"i002_2m_segue";"i003_2m_vira";"i004_2m_cabeca";"i005_2m_maos";"i006_2m_ri";"i007_2m_sentada";"i008_2m_sons";"i009_2m_olha";"i010_4m_cabeca";"i011_4m_maos";"i012_4m_ri";"i013_4m_sentada";"i014_4m_sons";"i015_4m_olha";"i016_4m_barriga";"i017_4m_brinquedo";"i018_4m_procura";"i019_4m_segura";"i020_6m_sons";"i021_6m_olha";"i022_6m_barriga";"i023_6m_brinquedo";"i024_6m_procura";"i025_6m_segura";"i026_6m_bracos";"i027_6m_sentada";"i028_6m_mao";"i029_6m_puxa";"i030_9m_bracos";"i031_9m_sentada";"i032_9m_mao";"i033_9m_puxa";"i034_9m_brinca";"i035_9m_mama";"i036_9m_olha";"i037_9m_sons";"i038_9m_anda";"i039_9m_pedidos";"i040_12m_mao";"i041_12m_puxa";"i042_12m_brinca";"i043_12m_mama";"i044_12m_olha";"i045_12m_sons";"i046_12m_anda";"i047_12m_pedidos";"i048_12m_corre";"i049_12m_escadas";"i050_15m_mama";"i051_15m_olha";"i052_15m_sons";"i053_15m_anda";"i054_15m_pedidos";"i055_15m_corre";"i056_15m_escadas";"i057_15m_chuta";"i058_15m_objetos";"i059_15m_corpo";"i060_18m_corre";"i061_18m_escadas";"i062_18m_chuta";"i063_18m_objetos";"i064_18m_corpo";"i065_18m_sozinha";"i066_18m_eu";"i067_18m_pula";"i068_18m_combina";"i069_18m_ajuda";"i070_24m_corpo";"i071_24m_sozinha";"i072_24m_eu";"i073_24m_pula";"i074_24m_combina";"i075_24m_ajuda";"i076_24m_cor";"i077_24m_atencao";"i078_24m_nome" ...
#
# Linha 2: "Norte";"";"Urbano";"02";"Masculino";"Filho(a), enteado(a)";1;11092017;"22 meses";1;"                              ";"01";27;2;3;"Branca";"Não, nunca frequentou";NA;NA;"       ";"                                        ";NA;"                                        ";"22072019";"22/07/2019 18:13";"                ";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";1;"Não";"Sim";1;"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Sim";"Não";"D    ";"Não";"Não";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Sim";"Sim";"Não";"Não";"Sim";"Sim";1041;"Sim";"Não";"Sim";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";38;2900;49;"Cesariana de urgência (Não agendada)";"Recusou o uso de chupeta";NA;NA;NA;NA;"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";"C      ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"                                        ";NA;22072019;22;11092017;38;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Um pouco";"Um pouco";"Um pouco";"Ainda não";"Ainda não";"Ainda não";"Ainda não";"Ainda não";"Ainda não";"Ainda não";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"1a10m ";"1";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Sim";"C         ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Desempregado e ativamente procurando por trabalho";NA;"                                        ";"Sim";"Já frequentou";"1°ano do ensino médio";2;2;"Sim";7;8;48;68;20;NA;NA;"Sim";1;"Horas";"Não";"Não";"Sim";"D      ";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"                                        ";3;"Dias";"Não";"Não";"Não";"Não";"H        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Sim, ainda usa";11;"Meses";"Mais ou menos";"Não";"Sim";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, sempre";"Sim, para todos esses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Não";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 1";"Às vezes";"Nunca";"Nunca";"Sempre";"Às vezes";"Raramente";"Sempre";"Sempre";"Nunca";NA;NA;NA;NA;NA;NA;NA;NA;"Discordo totalmente";"Discordo totalmente";"Discordo totalmente";"Discordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo parcialmente";"Pessoa 1";"Apartamento";"                              ";"Cedido de outra forma";NA;5;"Sim";1;1;1;"Fossa rudimentar";"                              ";"Poço ou nascente na propriedade";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";859,598538120578;952,024118212783;7,21428571428571;1355,23329571831;1337,77078486162;1176,15209761954;1265,96752307336;1133,55963929134;1269,04677641023;1117,03885163964;1115,6228922382;1136,22025471506;1135,8638493108;1192,20266393483;1225,45717959063;1104,65027369481;1229,43604768866;1116,25497434697;1160,45122011024;1163,15806149153;1283,48488591922;1205,44262835817;1131,73726687159;1205,02909554738;1272,96504192487;1208,81226766186;1457,48973249519;1294,69586663512;119,152272610773;"NorteMasculino3";"Sim";"A       ";"Sim";"Não";"Não";"Não";"Não ...
#
# Linha 3: "Norte";"";"Urbano";"03";"Feminino";"Filho(a), enteado(a)";4;6042015;"51 meses";1;"                              ";"01";27;2;3;"Branca";"Sim, creche ou escola pública";"Somente de tarde";"Sim";"D      ";"                                        ";NA;"                                        ";"22072019";"22/07/2019 18:13";"                ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";NA;NA;"Sim";1;"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Sim";"Não";"D    ";"Não";"Sim";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";1041;"Sim";"Não";"Sim";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";42;4300;51;"Cesariana de urgência (Não agendada)";"Já usou chupeta, mas não usa mais";3;"Dias";2;"Anos";"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Sim";"Não";"Não";"Sim";"Não";"Sim";"Não";"                                        ";"B      ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"                                        ";NA;22072019;51;6042015;42;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Muito";"Um pouco";"Muito";"Muito";"Ainda não";"Um pouco";"Muito";"Um pouco";"Ainda não";"Um pouco";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"4a    ";"4";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Sim";"C         ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Desempregado e ativamente procurando por trabalho";NA;"                                        ";"Sim";"Já frequentou";"1°ano do ensino médio";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";NA;NA;NA;NA;NA;NA;"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Sim";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, sempre";"Sim, para todos esses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Não";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 1";"Às vezes";"Nunca";"Nunca";"Sempre";"Às vezes";"Raramente";"Sempre";"Sempre";"Nunca";"Sempre";"Nunca";"Nunca";"Sempre";"Concordo parcialmente";"Concordo totalmente";"Concordo totalmente";"Discordo totalmente";"Discordo totalmente";"Discordo totalmente";"Discordo totalmente";"Discordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo parcialmente";"Pessoa 1";"Apartamento";"                              ";"Cedido de outra forma";NA;5;"Sim";1;1;1;"Fossa rudimentar";"                              ";"Poço ou nascente na propriedade";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";859,598538120578;952,024118212783;7,21428571428571;1224,11987548791;1223,5984567782;1176,15209761954;1145,65346481917;1102,24069423863;1153,11435782072;1117,03885163964;1115,6228922382;1136,22025471506;1135,8638493108;1162,56769372583;1190,23798545548;1104,65027369481;1229,43604768866;1116,25497434697;1160,45122011024;1163,15806149153;1189,37007567032;1101,00047444093;1131,73726687159;1101,37726615142;1160,40114498371;1143,41440518452;1311,03535974787;1242,39986523859;119,152272610773;"NorteFeminino6";"Sim";"A       ";"Sim";"Não";"Não";"Não" ...
#
# Linha 4: "Norte";"";"Urbano";"02";"Feminino";"Filho(a), enteado(a)";2;21122016;"30 meses";1;"                              ";"01";22;2;3;"Branca";"Não, nunca frequentou";NA;NA;"       ";"                                        ";NA;"                                        ";"18072019";"22/07/2019 09:00";"                ";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";NA;NA;"Sim";2;"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Sim";"Não";"D    ";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Sim";"Sim";"Sim";"Sim";"Não";"Sim";"Não";"Não";"Sim";"Não";"Não";1041;"Não";"Não";"Sim";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";42;2820;52;"Normal";"Recusou o uso de chupeta";NA;NA;NA;NA;"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;18072019;30;21122016;42;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Ainda não";"Muito";"Um pouco";"Ainda não";"Muito";"Ainda não";"Muito";"Ainda não";"Um pouco";"Ainda não";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"2a7m  ";"2";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Sim";"B         ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Fora do mercado de trabalho, não trabalha e não procura ativamente por trabalho";"Dona-de-casa/do lar";"                                        ";"Sim";"Já frequentou";"3°ano do ensino médio";2;2;"Sim";12;6;52;73;21;NA;NA;"Sim";0;"Horas";"Não";"Não";"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";3;"Meses";"Não";"Não";"Não";"Não";"H        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Sim, já usou mas não usa mais";1;"Anos";"Não";"Não";"Sim";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, quase sempre";"Sim, para a maioria desses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Não";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 4";"Às vezes";"Nunca";"Nunca";"Sempre";"Raramente";"Quase sempre";"Sempre";"Quase sempre";"Quase sempre";NA;NA;NA;NA;NA;NA;NA;NA;"Concordo parcialmente";"Concordo parcialmente";"Discordo totalmente";"Discordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo parcialmente";"Pessoa 1";"Casa";"                              ";"Cedido de outra forma";NA;6;"Sim";2;1;1;"Fossa séptica";"                              ";"Rede geral de distribuição";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";859,598538120578;942,34443589461;7,21428571428571;1224,11987548791;1223,5984567782;1033,55733931651;1133,66199402664;1058,31099452113;1130,7827720484;1043,10591924096;1017,69776153837;1028,05582682471;1028,66558232223;1162,56769372583;1190,23798545548;1097,61660447049;1103,53228633805;1017,68599558657;1025,58237602151;1024,19233264483;1189,37007567032;1101,00047444093;1110,31750878344;1101,37726615142;1136,2097488585;1143,41440518452;1311,03535974787;1242,39986523859;119,152272610773;"NorteFeminino4";"Sim";"A       ";"Sim";"Não";"Não";"Não";" ...
#
# Linha 5: "Norte";"";"Urbano";"03";"Masculino";"Filho(a), enteado(a)";4;13112014;"56 meses";1;"                              ";"01";22;2;3;"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Sim, creche ou escola pública";"Somente de manhã";"Sim";"B      ";"                                        ";NA;"                                        ";"18072019";"22/07/2019 08:59";"                ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";NA;NA;"Sim";2;"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Sim";"Não";"D    ";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Sim";"Não";"Sim";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";1041;"Não";"Não";"Sim";"Não";NA;NA;"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";NA;NA;NA;"Sim";"Sim";"Sim";"Sim";"Sim";NA;NA;NA;"Sim";NA;NA;NA;42;2720;49;"Normal";"Já usou chupeta, mas não usa mais";2;"Dias";10;"Meses";"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;18072019;56;13112014;42;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Ainda não";"Ainda não";"Um pouco";"Um pouco";"Ainda não";"Um pouco";"Muito";"Ainda não";"Um pouco";"Ainda não";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"4a    ";"4";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Sim";"B         ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Fora do mercado de trabalho, não trabalha e não procura ativamente por trabalho";"Dona-de-casa/do lar";"                                        ";"Sim";"Já frequentou";"3°ano do ensino médio";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";NA;NA;NA;NA;NA;NA;"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Sim";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, quase sempre";"Sim, para a maioria desses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Não";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 4";"Às vezes";"Nunca";"Nunca";"Sempre";"Raramente";"Quase sempre";"Sempre";"Quase sempre";"Quase sempre";"Sempre";"Quase sempre";"Quase sempre";"Às vezes";"Concordo totalmente";"Concordo totalmente";"Nem concordo nem discordo";"Concordo totalmente";"Concordo parcialmente";"Concordo parcialmente";"Discordo totalmente";"Discordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo parcialmente";"Pessoa 1";"Casa";"                              ";"Cedido de outra forma";NA;6;"Sim";2;1;1;"Fossa séptica";"                              ";"Rede geral de distribuição";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";859,598538120578;942,34443589461;7,21428571428571;0;0;1033,55733931651;1133,66199402664;1058,31099452113;1130,7827720484;1043,10591924096;1017,69776153837;1028,05582682471;1028,66558232223;0;0;0;1103,53228633805;1017,68599558657;1025,58237602151;1024,19233264483;1189,37007567032;0;0;0;1136,2097488585;0;0;0;119,152272610773;"NorteMasculino6";"Sim";"A       ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                              ";3;1520;"De R$ 1.001, ...
#
# Linha 6: "Norte";"";"Urbano";"02";"Feminino";"Filho(a), enteado(a)";0;2092018;"10 meses";1;"                              ";"01";33;2;2;"Branca";"Não, nunca frequentou";NA;NA;"       ";"                                        ";NA;"                                        ";"18072019";"18/07/2019 18:02";"                ";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";2;"Não";"Sim";2;"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"A    ";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";"Sim";"Não";"Não";"Sim";"Não";"Sim";"Não";"Não";"Não";1041;"Sim";"Não";"Não";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";40;3030;50;"Normal";"Nunca usou porque nunca foi oferecido";NA;NA;NA;NA;"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;18072019;10;2092018;40;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"10m16d";"0";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Sim";"C         ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Fora do mercado de trabalho, não trabalha e não procura ativamente por trabalho";"Aposentado";"                                        ";"Sim";"Já frequentou";"2ª série/ 3°ano do ensino fundamental";4;4;"Sim";6;12;73;85;12;NA;NA;"Sim";0;"Horas";"Sim";"Sim";"Sim";"C      ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"                                        ";3;"Dias";"Não";"Não";"Sim";"Não";"H        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não, nunca usou";NA;NA;"Não";"Pouco";"Sim";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, quase sempre";"Sim, para todos esses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Sim, sempre";"Sim, sempre";"AF                    ";"Sim, pessoa 1";"Não";"Não";"Não";"Não";"Sim, pessoa 6";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Pessoa 1";"Pessoa 3";"Às vezes";"Às vezes";"Às vezes";"Sempre";"Às vezes";"Sempre";"Sempre";"Raramente";"Nunca";NA;NA;NA;NA;NA;NA;NA;NA;"Concordo totalmente";"Concordo totalmente";"Discordo parcialmente";"Nem concordo nem discordo";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Pessoa 1";"Casa";"                              ";"Próprio de algum morador - já pago";NA;5;"Não";2;1;1;"Fossa rudimentar";"                              ";"Rede geral de distribuição";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";859,598538120578;1117,57749349552;7,21428571428571;1355,23329571831;1337,77078486162;1176,15209761954;1302,01437216148;1198,29439254311;1298,86313571283;1126,92016070791;1120,94997323745;1100,51705519942;1098,67530729338;1192,20266393483;1225,45717959063;1212,69816861089;1229,43604768866;1122,28603356716;1165,34025959646;1164,7324002274;1283,48488591922;1259,66105590237;1203,96203832239;1257,83818732772;1292,29296426102;1274,98275221168;1457 ...
#
# Linha 7: "Norte";"";"Urbano";"03";"Masculino";"Neto(a), bisneto(a)";0;27012019;"5 meses";2;"                              ";"02";19;3;3;"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não, nunca frequentou";NA;NA;"       ";"                                        ";NA;"                                        ";"23072019";"                ";"                ";"Sim";"Sim";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";NA;NA;"Sim";1;"B     ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Sim";"Não";"D    ";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Sim";1041;"Sim";"Não";"Não";"Não";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";40;2975;49;"Normal";"Usa chupeta";3;"Meses";NA;NA;"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;23072019;5;27012019;40;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Um pouco";"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";"Muito";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"      ";"0";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não";"C         ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Fora do mercado de trabalho, não trabalha e não procura ativamente por trabalho";"Não procura por trabalho";"                                        ";"Sim";"Já frequentou";"8ª série/ 9°ano do ensino fundamental";1;1;"Sim";10;8;47;56;9;NA;NA;"Sim";0;"Horas";"Sim";"Não";"Sim";"C      ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"                                        ";2;"Meses";"Não";"Não";"Sim";"Não";"H        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Sim, ainda usa";3;"Meses";"Muito";"Não";"Sim";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, quase sempre";"Sim, para a maioria desses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Não";"Sim, quase sempre";"ABDE         ...
#
# Linha 8: "Norte";"";"Urbano";"02";"Masculino";"Filho(a), enteado(a)";3;11112015;"44 meses";1;"                              ";"01";27;2;2;"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não, nunca frequentou";NA;NA;"       ";"                                        ";NA;"                                        ";"23072019";"25/07/2019 08:52";"                ";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";NA;NA;"Sim";1;"AB    ";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"A    ";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Sim";"Não";"Não";"Sim";"Sim";"Sim";1041;"Não";"Sim";"Sim";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";38;3800;52;"Cesariana de urgência (Não agendada)";"Recusou o uso de chupeta";NA;NA;NA;NA;"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"E     ";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Sim";"Não";"Não";"Sim";"Sim";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;23072019;44;11112015;38;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Um pouco";"Ainda não";"Ainda não";"Ainda não";"Ainda não";"Ainda não";"Um pouco";"Ainda não";"Ainda não";"Ainda não";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"3a8m  ";"3";"Preta";"Sim";"C         ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Trabalho irregular e sem horário fixo (bicos)";NA;"                                        ";"Sim";"Já frequentou";"1°ano do ensino médio";3;3;"Sim";8;6;58;78;20;NA;NA;"Sim";0;"Horas";"Não";"Não";"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";15;"Dias";"Não";"Não";"Não";"Não";"H        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Sim, ainda usa";6;"Meses";"Não";"Mais ou menos";"Sim";"Sim";"Sim";"Sim";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, sempre";"Sim, para todos esses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Sim, quase sempre";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 3";"Quase sempre";"Sempre";"Quase sempre";"Sempre";"Raramente";"Sempre";"Sempre";"Sempre";"Raramente";"Sempre";"Nunca";"Nunca";"Nunca";"Discordo parcialmente";"Concordo parcialmente";"Concordo totalmente";"Concordo totalmente";"Concordo parcialmente";"Concordo parcialmente";"Concordo parcialmente";"Nem concordo nem discordo";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Pessoa 1";"Casa";"                              ";"Próprio de algum morador - ainda pagando";NA;6;"Sim";2;1;1;"Fossa séptica";"                              ";"Rede geral de distribuição";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";859,598538120578;962,498575950913;7,21428571428571;1224,11987548791;1223,5984567782;1033,55733931651;1133,66199402664;1058,31099452113;1130,7827720484;1043,10591924096;1017,69776153837;1028,05582682471;1028,66558232223;1162,56769372583;1190,23798545548;1097,61660447049;1103,53228633805;1017,68599558657;1025,58237602151;1024,19233264483;1189,37007567032;1101,00047444093;1110,31750878344;1101,37726615142;1136,2097488585;1143,41440518452 ...
#
# Linha 9: "Norte";"";"Urbano";"02";"Feminino";"Filho(a), enteado(a)";4;17062015;"49 meses";1;"                              ";"01";46;2;2;"Branca";"Sim, creche ou escola pública";"Somente de manhã";"Sim";"AC     ";"                                        ";NA;"                                        ";"22072019";"23/07/2019 18:18";"                ";"Não";"Sim";"Sim";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";NA;NA;"Sim";1;"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"A    ";"Sim";"Sim";"Não";"Sim";"Sim";"Sim";"Não";"Sim";"Sim";"Não";"Sim";"Sim";"Não";"Sim";"Sim";"Não";"Não";"Não";"Sim";1041;"Sim";"Não";"Não";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";40;3750;48;"Cesariana de urgência (Não agendada)";"Já usou chupeta, mas não usa mais";18;"Meses";2;"Anos";"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Sim";"Sim";"Não";"Sim";"Sim";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;22072019;49;17062015;40;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Muito";"Muito";"Muito";"Muito";"Um pouco";"Ainda não";"Um pouco";"Um pouco";"Ainda não";"Muito";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"4a    ";"4";"Branca";"Sim";"A         ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Fora do mercado de trabalho, não trabalha e não procura ativamente por trabalho";"Dona-de-casa/do lar";"                                        ";"Sim";"Já frequentou";"Ensino superior completo";1;1;"Sim";4;7;55;67;12;NA;NA;"Sim";0;"Horas";"Não";"Sim";"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";6;"Meses";"Não";"Não";"Não";"Não";"H        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não, nunca usou";NA;NA;"Não";"Muito";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, sempre";"Sim, para todos esses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Sim, sempre";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 1";"Sempre";"Sempre";"Sempre";"Sempre";"Às vezes";"Às vezes";"Às vezes";"Às vezes";"Às vezes";"Sempre";"Nunca";"Nunca";"Nunca";"Concordo parcialmente";"Concordo totalmente";"Concordo parcialmente";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo parcialmente";"Concordo parcialmente";"Concordo parcialmente";"Pessoa 1";"Casa";"                              ";"Próprio de algum morador - já pago";NA;7;"Sim";2;2;2;"Fossa séptica";"                              ";"Poço ou nascente na propriedade";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";859,598538120578;1045,33824326017;7,21428571428571;1224,11987548791;1223,5984567782;1176,15209761954;1145,65346481917;1133,55963929134;1153,11435782072;1126,92016070791;1120,94997323745;1100,51705519942;1098,67530729338;1192,20266393483;1225,45717959063;1104,65027369481;1229,43604768866;1122,28603356716;1160,45122011024;1163,15806149153;1283,48488591922;1205,44262835817;1131,73726687159;1205,02909554738;1160,40114498371;1208,81226766 ...
#
# Linha 10: "Norte";"";"Urbano";"03";"Masculino";"Neto(a), bisneto(a)";1;23032018;"16 meses";2;"                              ";"02";39;3;3;"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não, nunca frequentou";NA;NA;"       ";"                                        ";NA;"                                        ";"25072019";"25/07/2019 17:44";"                ";"Sim";"Sim";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim";1;"Não";"Sim";2;"AB    ";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"A    ";"Sim";"Sim";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";1041;"Sim";"Sim";"Sim";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";36;2600;48;"Normal";"Recusou o uso de chupeta";NA;NA;NA;NA;"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;25072019;15;20042018;36;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Um pouco";"Muito";"Um pouco";"Muito";"Muito";"Muito";"Ainda não";"Um pouco";"Ainda não";"Ainda não";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"1a4m  ";"1";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não";"A         ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Trabalho irregular e sem horário fixo (bicos)";NA;"                                        ";"Sim";"Já frequentou";"2°ano do ensino médio";3;2;"Sim";5;8;62;70;8;NA;NA;"Sim";5;"Dias";"Sim";"Sim";"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";6;"Meses";"Não";"Não";"Não";"Sim";"H        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não, nunca usou";NA;NA;"Não";"Mais ou menos";"Sim";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, sempre";"Sim, para todos esses alimentos";"Sim, quase sempre";"Sim, para todos esses alimentos";"Sim";"Não";"Sim, às vezes";"ABD                   ";"Sim, pessoa 1";"Sim, pessoa 2";"Não";"Sim, pessoa 4";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Pessoa 1";"Pessoa 1";"Às vezes";"Às vezes";"Sempre";"Sempre";"Raramente";"Raramente";"Sempre";"Raramente";"Raramente";NA;NA;NA;NA;NA;NA;NA;NA;"Discordo parcialmente";"Discordo parcialmente";"Discordo parcialmente";"Discordo parcialmente";"Concordo totalmente";"Concordo totalmente";"Concordo parcialmente";"Pessoa 2";"Casa";"                              ";"Próprio de algum morador - já pago";NA;5;"Sim";2;1;1;"Fossa rudimentar";"                              ";"Rede geral de distribuição";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";859,598538120578;858,709993165401;7,21428571428571;1224,11987548791;1223,5984567782;1033,55733931651;1133,66199402664;1058,31099452113;1130,7827720484;1043,10591924096;1017,69776153837;1028,05582682471;1028,66558232223;1162,56769372583;1190,23798545548;1097,61660447049;1103,53228633805;1017,68599558657;1025,58237602151;1024,19233264483;1189,37007567032;1101,00047444093;1110,31750878344;1101,37726615142;1136,2097488585;1143,41440518452;1311,0353597 ...
#
# Linha 11: "Norte";"";"Urbano";"03";"Feminino";"Filho(a), enteado(a)";0;31012019;"5 meses";2;"                              ";"02";16;3;3;"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não, nunca frequentou";NA;NA;"       ";"                                        ";NA;"                                        ";"22072019";"                ";"                ";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Não";NA;NA;"Não";NA;"      ";NA;NA;NA;NA;NA;NA;"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"D    ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";1041;"Sim";"Não";"Não";"Não";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";"Não elegível ou não possui nenhum dos 12 parâmetros";40;3500;49;"Cesariana de urgência (Não agendada)";"Usa chupeta";2;"Meses";NA;NA;"Centro de Especialidades, Policlínica pública ou PAM – Posto de Assistência Médica";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Sim";"Não";"Não";"Sim";"Não";"Sim";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;22072019;5;31012019;40;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Um pouco";"Um pouco";"Muito";"Muito";"Um pouco";"Muito";"Muito";"Muito";"Ainda não";"Um pouco";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"      ";"0";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Sim";"C         ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"Fora do mercado de trabalho, não trabalha e não procura ativamente por trabalho";"Dona-de-casa/do lar";"                                        ";"Sim";"Já frequentou";"8ª série/ 9°ano do ensino fundamental";1;1;"Sim";3;12;63;70;7;NA;NA;"Sim";1;"Dias";"Não";"Não";"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";2;"Meses";"Não";"Não";"Não";"Não";"C        ";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, ainda usa";4;"Meses";"Pouco";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 2";"Sim, às vezes";"Sim, para a maioria desses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Sim, sempre";"Sim, quase sempre";"AB       ...
#
# ...
#
# Linha 18: "Norte";"";"Urbano";"02";"Feminino";"Filho(a), enteado(a)";1;22082017;"22 meses";1;"                              ";"01";20;2;3;"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não";NA;NA;"       ";"                                        ";NA;"                                        ";"15072019";"15/07/2019 18:44";"                ";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";1;"Não";"Sim";2;"AE    ";"Sim";"Não";"Não";"Não";"Sim";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Sim";"Não";"D    ";"Não";"Não";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";1041;"Não";"Não";"Sim";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";41;4600;52;"Cesariana de urgência (Não agendada)";"Nunca usou porque nunca foi oferecido";NA;NA;NA;NA;"Unidade básica de saúde (posto ou centro de saúde ou unidade de saúde da família)";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;15072019;22;22082017;41;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Muito";"Muito";"Muito";"Ainda não";"Ainda não";"Um pouco";"Ainda não";"Muito";"Ainda não";"Ainda não";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"1a10m ";"1";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não";"H         ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"                                        ";"Trabalho irregular e sem horário fixo (bicos)";NA;"                                        ";"Sim";"Frequenta";"8ª série/ 9°ano do ensino fundamental";2;2;"Sim";4;10;999,9;75;10;NA;NA;"Sim";0;"Horas";"Não";"Sim";"Sim";"A      ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";3;"Meses";"Não";"Não";"Sim";"Não";"CD       ";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim, já usou mas não usa mais";15;"Dias";"Não";"Não";"Sim";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, sempre";"Sim, para todos esses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Sim, sempre";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 1";"Sempre";"Sempre";"Sempre";"Sempre";"Nunca";"Às vezes";"Sempre";"Sempre";"Sempre";NA;NA;NA;NA;NA;NA;NA;NA;"Concordo totalmente";"Concordo parcialmente";"Concordo totalmente";"Discordo totalmente";"Concordo totalmente";"Concordo totalmente";"Discordo totalmente";"Pessoa 1";"Casa";"                              ";"Cedido de outra forma";NA;3;"Não";1;1;1;"Fossa séptica";"                              ";"Rede geral de distribuição";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";2093,96482229587;2437,37047968399;11,1666666666667;3301,32116492755;3258,78283823051;2865,08295310682;3083,87153063399;2761,32857768718;3091,37253008944;2721,08426985607;2717,63502111388;2767,80978357091;2766,94158714444;2904,18181118029;2985,18914527602;2954,10845007466;2994,88158827162;2719,17476047109;2826,83592996096;2833,42974135152;3126,54347567805;2936,43409933744;2756,88931497225;2935,42674169285;3100,91734640569;2944,64247319203;3550,4157968615;3153,85320016158;187,519237817541;"NorteFeminino3";"Sim";"A     ...
#
# Linha 19: "Norte";"";"Urbano";"03";"Feminino";"Filho(a), enteado(a)";4;8092014;"58 meses";1;"                              ";"01";20;2;3;"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Sim, creche ou escola particular";"Somente de tarde";"Sim";"D      ";"                                        ";NA;"                                        ";"15072019";"15/07/2019 18:44";"                ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";1;"Não";"Sim";2;"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Sim";"Não";"D    ";"Não";"Não";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";1041;"Não";"Não";"Sim";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";36;3460;50;"Normal";"Nunca usou porque nunca foi oferecido";NA;NA;NA;NA;"Unidade básica de saúde (posto ou centro de saúde ou unidade de saúde da família)";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;15072019;58;8092014;36;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Ainda não";"Muito";"Ainda não";"Muito";"Muito";"Muito";"Ainda não";"Um pouco";"Um pouco";"Muito";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"4a    ";"4";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não";"H         ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"                                        ";"Trabalho irregular e sem horário fixo (bicos)";NA;"                                        ";"Sim";"Frequenta";"8ª série/ 9°ano do ensino fundamental";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";NA;NA;NA;NA;NA;NA;"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Sim";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 1";"Sim, sempre";"Sim, para todos esses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Sim, sempre";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 1";"Sempre";"Sempre";"Sempre";"Sempre";"Nunca";"Às vezes";"Sempre";"Sempre";"Sempre";"Sempre";"Sempre";"Sempre";"Sempre";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo parcialmente";"Concordo totalmente";"Discordo totalmente";"Concordo totalmente";"Concordo totalmente";"Discordo totalmente";"Pessoa 1";"Casa";"                              ";"Cedido de outra forma";NA;3;"Não";1;1;1;"Fossa séptica";"                              ";"Rede geral de distribuição";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";2093,96482229587;2437,37047968399;11,1666666666667;2981,93149926615;2980,66133373258;2517,72497785578;2761,57791177233;2578,02438615286;2754,56418470015;2540,98512730692;2479,09136403355;2504,32340361342;2505,80875579282;2831,9916172985;2899,3958937544;2673,77206475268;2688,18254729916;2479,06270241064;2498,2981269966;2494,91200917164;2897,28168290077;2682,01510422646;2704,71121327755;2682,9329612866;2767,78419151474;2785,33459002567;3193,65587812688;3026,46118817597;187,519237817541;"NorteFeminino6";"Sim";"A       ";"Sim";"Nã ...
#
# Linha 20: "Norte";"";"Urbano";"04";"Feminino";"Neto(a), bisneto(a)";3;25042016;"38 meses";2;"                              ";"02";17;5;4;"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não";NA;NA;"       ";"                                        ";NA;"                                        ";" 9072019";"10/07/2019 08:50";"                ";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";1;"Não";"Sim";2;"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Sim";"Sim";"Não";"Não";"Não";"Não";"A    ";"Não";"Não";"Não";"Sim";"Sim";"Não";"Não";"Não";"Sim";"Não";"Não";"Sim";"Não";"Sim";"Não";"Não";"Não";"Não";"Sim";1041;"Não";"Não";"Sim";"Não";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";"Sim";39;3612;51;"Cesariana agendada (eletiva)";"Já usou chupeta, mas não usa mais";1;"Dias";18;"Meses";"Hospital público/ambulatório";"                                        ";"A     ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;"                                        ";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"                                        ";"F      ";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"                                        ";NA;9072019;38;25042016;39;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Muito";"Muito";"Muito";"Um pouco";"Ainda não";"Um pouco";"Ainda não";"Um pouco";"Muito";"Muito";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Não";"       ";NA;NA;NA;NA;NA;NA;NA;"3a2m  ";"3";"Parda (mulata, cabocla, cafuza, mameluca ou mestiça)";"Não";"H         ";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"                                        ";"Desempregado e ativamente procurando por trabalho";NA;"                                        ";"Sim";"Já frequentou";"7ª série/ 8°ano do ensino fundamental";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"       ";NA;NA;NA;NA;NA;NA;NA;"                                        ";NA;NA;NA;NA;NA;NA;"         ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Sim";"Não";"Sim";"Sim";"Não";"Não";"Não";"Não";"Sim";"Não";"Não";"Não";"Não";"Não";"Sim, todos os dias da semana";"Pessoa 2";"Sim, sempre";"Sim, para todos esses alimentos";"Sim, sempre";"Sim, para todos esses alimentos";"Sim";"Não";"Não";"                      ";NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;NA;"Pessoa 1";"Pessoa 1";"Às vezes";"Às vezes";"Às vezes";"Sempre";"Nunca";"Raramente";"Às vezes";"Raramente";"Às vezes";"Quase sempre";"Às vezes";"Às vezes";"Raramente";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Concordo totalmente";"Discordo totalmente";"Discordo totalmente";"Discordo totalmente";"Nem concordo nem discordo";"Concordo totalmente";"Concordo totalmente";"Nem concordo nem discordo";"Pessoa 2";"Casa";"                              ";"Alugado";350;7;"Sim";3;1;1;"Fossa séptica";"                              ";"Rede geral de distribuição";"                              ";"Coletado diretamente por serviço de limpeza";"                              ";"Rede geral (companhia distribuidora)";2093,96482229587;2200,73491835312;11,1666666666667;3301,32116492755;3258,78283823051;2865,08295310682;2790,78889445041;2685,03625481377;2808,96348037087;2721,08426985607;2717,63502111388;2767,80978357091;2766,94158714444;2904,18181118029;2985,18914527602;2690,9059421085;2994,88158827162;2719,17476047109;2826,83592996096;2833,42974135152;3126,54347567805;2936,43409933744;2756,88931497225;2935,42674169285;2826,71394795566;2944,64247319203;3550,4157968615;3153,85320016158;187,519237817541;"NorteFeminino5";"Sim";"A       ";"Sim";"Não";"Não";"Não";"Não";"Não";"Não";"Não";"           ...

# %% [markdown]
# ### **03. Pré-processamento dos dados para produzir o banco de dados para análise exploratória.**

# %%
# Recomendamos que a equipe divida em várias células de código cada etapa do
# processamento e que utilize comentários para descrever cada etapa.

# %% [markdown]
# Este notebook realiza o carregamento de um dataset, selecionando apenas as colunas relevantes para a análise. Em seguida, procede com a remoção de colunas desnecessárias, o cálculo da porcentagem de dados ausentes e a formatação dos nomes das colunas. Por fim, gera um novo dataset com as variáveis selecionadas e.

# %%
# Lista de colunas que você deseja manter no dataset
colunas_que_eu_quero = [
    'a00_regiao', 'a06_domicilio', 'p03_ocupacao', 'a11_situacao', 'b00_numero', 'b02_sexo', 'b03_relacao',
    'b04_idade', 'b05_data', 'b05a_idade_em_meses', 'bb04_idade_da_mae', 'p02_tipo_de_domicilio', 'p06_cozinha',
    'h02_peso', 'h03_altura', 'h11_alergia', 'h13_diarreia', 'h14_tosse', 'h15_respiracao', 'e01_leite_peito',
    'e07_leite_vaca_liquido', 'e06_leite_vaca_po', 'e05_cha', 'e10_formula_infantil', 'e16_comida_sal',
    'e22_legumes', 'e26_feijao', 'e27_carne', 'e33_refrigerante', 'e31_salgadinhos', 'e35_biscoito',
    'l01_morador_alim_acabassem', 'l02_morador_alim_acabaram', 'l03_morador_saudavel', 'i004_2m_cabeca',
    'i028_6m_mao', 'vd_zhfa', 'vd_zwaz', 'vd_zimc', 'm03_alimentos_basicos', 'n01_frutas', 'n02_legumes',
    'n03_verduras', 'n04_feijao', 'n05_suco', 'peso_crianca', 'h12_alergias', 'h121_alergia_leite', 'h122_alergia_ovos',
    'h126_alergia_frutas', 'k29_alimentacao'
]

# %%
# Carregar o dataset com as colunas selecionadas
dataset = pd.read_csv(
    r'/content/[1] Dataset_Original.csv',
    on_bad_lines='skip', sep=';', usecols=colunas_que_eu_quero
)

# %%
# Exibir as colunas do dataset para verificação
print(dataset.columns)
# Out:
# Index(['a00_regiao', 'a06_domicilio', 'a11_situacao', 'b00_numero', 'b02_sexo',
#        'b03_relacao', 'b04_idade', 'b05_data', 'b05a_idade_em_meses',
#        'bb04_idade_da_mae', 'e01_leite_peito', 'e05_cha', 'e06_leite_vaca_po',
#        'e07_leite_vaca_liquido', 'e10_formula_infantil', 'e16_comida_sal',
#        'e22_legumes', 'e26_feijao', 'e27_carne', 'e31_salgadinhos',
#        'e33_refrigerante', 'e35_biscoito', 'h02_peso', 'h03_altura',
#        'h11_alergia', 'h12_alergias', 'h121_alergia_leite',
#        'h122_alergia_ovos', 'h126_alergia_frutas', 'h13_diarreia', 'h14_tosse',
#        'h15_respiracao', 'i004_2m_cabeca', 'i028_6m_mao', 'k29_alimentacao',
#        'l01_morador_alim_acabassem', 'l02_morador_alim_acabaram',
#        'l03_morador_saudavel', 'm03_alimentos_basicos', 'n01_frutas',
#        'n02_legumes', 'n03_verduras', 'n04_feijao', 'n05_suco',
#        'p02_tipo_de_domicilio', 'p03_ocupacao', 'p06_cozinha', 'peso_crianca',
#        'vd_zwaz', 'vd_zimc', 'vd_zhfa'],
#       dtype='object')

# %%
# Exibir as primeiras 5 linhas do dataset
print(dataset.head(5))
# Out:
#   a00_regiao  a06_domicilio a11_situacao  b00_numero   b02_sexo  \
# 0      Norte            NaN       Urbano           2  Masculino
# 1      Norte            NaN       Urbano           3   Feminino
# 2      Norte            NaN       Urbano           2   Feminino
# 3      Norte            NaN       Urbano           3  Masculino
# 4      Norte            NaN       Urbano           2   Feminino
#
#             b03_relacao  b04_idade  b05_data b05a_idade_em_meses  \
# 0  Filho(a), enteado(a)          1  11092017            22 meses
# 1  Filho(a), enteado(a)          4   6042015            51 meses
# 2  Filho(a), enteado(a)          2  21122016            30 meses
# 3  Filho(a), enteado(a)          4  13112014            56 meses
# 4  Filho(a), enteado(a)          0   2092018            10 meses
#
#    bb04_idade_da_mae  ... n03_verduras n04_feijao   n05_suco  \
# 0               27.0  ...        Nunca     Sempre   Às vezes
# 1               27.0  ...        Nunca     Sempre   Às vezes
# 2               22.0  ...        Nunca     Sempre  Raramente
# 3               22.0  ...        Nunca     Sempre  Raramente
# 4               33.0  ...     Às vezes     Sempre   Às vezes
#
#   p02_tipo_de_domicilio                        p03_ocupacao p06_cozinha  \
# 0           Apartamento               Cedido de outra forma         Sim
# 1           Apartamento               Cedido de outra forma         Sim
# 2                  Casa               Cedido de outra forma         Sim
# 3                  Casa               Cedido de outra forma         Sim
# 4                  Casa  Próprio de algum morador - já pago         Não
#
#        peso_crianca vd_zwaz vd_zimc vd_zhfa
# 0  859,598538120578    -0,2    -0,2     NaN
# 1  859,598538120578    -0,5      -1     NaN
# 2  859,598538120578    -0,3    -0,7     NaN
# 3  859,598538120578     0,1    -0,7     NaN
# 4  859,598538120578    -0,6    -0,8     NaN
#
# [5 rows x 51 columns]

# %%
# Função para "embelezar" os nomes das colunas
def embelezar(nome_coluna: str):
    return str.join(" ", nome_coluna.split("_")[1:]).capitalize()

# %%
# Aplicar a função de embelezamento (exemplo de uso para uma coluna)
col = "bb04_idade_da_mae"
print(embelezar(col))
# Out:
# Idade da mae

# %%
# Calcular a porcentagem de dados faltantes por coluna
percent_faltante = (dataset.isnull().sum() / len(dataset)) * 100
print(percent_faltante)
# Out:
# a00_regiao                      0.000000
# a06_domicilio                 100.000000
# a11_situacao                    0.000000
# b00_numero                      0.000000
# b02_sexo                        0.000000
# b03_relacao                     0.000000
# b04_idade                       0.000000
# b05_data                        0.000000
# b05a_idade_em_meses             0.000000
# bb04_idade_da_mae               0.075560
# e01_leite_peito                 0.000000
# e05_cha                         0.000000
# e06_leite_vaca_po               0.000000
# e07_leite_vaca_liquido          0.000000
# e10_formula_infantil            0.000000
# e16_comida_sal                  0.000000
# e22_legumes                     0.000000
# e26_feijao                      0.000000
# e27_carne                       0.000000
# e31_salgadinhos                 0.000000
# e33_refrigerante                0.000000
# e35_biscoito                    0.000000
# h02_peso                        0.000000
# h03_altura                      0.000000
# h11_alergia                     0.000000
# h12_alergias                    0.000000
# h121_alergia_leite             95.493887
# h122_alergia_ovos              95.493887
# h126_alergia_frutas            95.493887
# h13_diarreia                    0.000000
# h14_tosse                       0.000000
# h15_respiracao                  0.000000
# i004_2m_cabeca                 92.718780
# i028_6m_mao                    95.054266
# k29_alimentacao                16.506388
# l01_morador_alim_acabassem      0.000000
# l02_morador_alim_acabaram       0.000000
# l03_morador_saudavel            0.000000
# m03_alimentos_basicos           2.720154
# n01_frutas                      0.000000
# n02_legumes                     0.000000
# n03_verduras                    0.000000
# n04_feijao                      0.000000
# n05_suco                        0.000000
# p02_tipo_de_domicilio           0.000000
# p03_ocupacao                    0.000000
# p06_cozinha                     0.000000
# peso_crianca                    0.000000
# vd_zwaz                         0.006869
# vd_zimc                         1.353208
# vd_zhfa                        92.327243
# dtype: float64

# %%
# Remover colunas desnecessárias
colunas_n_quero = ['i004_2m_cabeca', 'i028_6m_mao', 'a06_domicilio']
dataset = dataset.drop(columns=colunas_n_quero)

# %%
# Lista das variáveis finais que você quer manter no novo dataset
variaveis_selecionadas = [
    "a00_regiao", "b02_sexo", "b04_idade", "b05_data", "b05a_idade_em_meses", "l01_morador_alim_acabassem",
    "l02_morador_alim_acabaram", "p02_tipo_de_domicilio", "p06_cozinha", "p03_ocupacao", "a11_situacao",
    "h14_tosse", "h15_respiracao", "m03_alimentos_basicos", 'n01_frutas', 'n02_legumes',
    'n03_verduras', 'n04_feijao', 'n05_suco', 'peso_crianca', 'h12_alergias', 'h121_alergia_leite', 'h122_alergia_ovos',
    'h126_alergia_frutas', 'k29_alimentacao'
]

# %%
# Criar um novo DataFrame com as variáveis selecionadas
novo_dataset = dataset[variaveis_selecionadas]

# %%
novo_dataset['n01_frutas'] = novo_dataset['n01_frutas'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
                                                                 'Quase sempre' : 3, 'Sempre' : 4})

novo_dataset['n02_legumes'] = novo_dataset['n02_legumes'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
                                                                 'Quase sempre' : 3, 'Sempre' : 4})

novo_dataset['n03_verduras'] = novo_dataset['n03_verduras'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
                                                                 'Quase sempre' : 3, 'Sempre' : 4})

novo_dataset['n04_feijao'] = novo_dataset['n04_feijao'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
                                                                 'Quase sempre' : 3, 'Sempre' : 4})

novo_dataset['n05_suco'] = novo_dataset['n05_suco'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
                                                                 'Quase sempre' : 3, 'Sempre' : 4})
# Out:
# <ipython-input-19-0ed5212a59ad>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   novo_dataset['n01_frutas'] = novo_dataset['n01_frutas'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   novo_dataset['n01_frutas'] = novo_dataset['n01_frutas'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   novo_dataset['n02_legumes'] = novo_dataset['n02_legumes'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   novo_dataset['n02_legumes'] = novo_dataset['n02_legumes'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   novo_dataset['n03_verduras'] = novo_dataset['n03_verduras'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   novo_dataset['n03_verduras'] = novo_dataset['n03_verduras'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   novo_dataset['n04_feijao'] = novo_dataset['n04_feijao'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   novo_dataset['n04_feijao'] = novo_dataset['n04_feijao'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   novo_dataset['n05_suco'] = novo_dataset['n05_suco'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,
# <ipython-input-19-0ed5212a59ad>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   novo_dataset['n05_suco'] = novo_dataset['n05_suco'].replace({'Nunca' : 0, 'Raramente' : 1, 'Às vezes' : 2,

# %%
novo_dataset.dropna(inplace = False, axis = 0)
# Out:
#              Região       Sexo  Idade  Data de Nascimento Idade em Meses  \
# 62            Norte  Masculino      2            30082016       34 meses
# 82            Norte  Masculino      1            24122017       19 meses
# 92            Norte   Feminino      2            18072016       34 meses
# 93            Norte  Masculino      0             3122018        6 meses
# 111           Norte  Masculino      4            28072014       59 meses
# ...             ...        ...    ...                 ...            ...
# 14492  Centro-Oeste  Masculino      1            19112017       17 meses
# 14523  Centro-Oeste   Feminino      2            25022017       25 meses
# 14530  Centro-Oeste  Masculino      2            23012017       29 meses
# 14551  Centro-Oeste  Masculino      1            14062017       23 meses
# 14552  Centro-Oeste  Masculino      3            30122015       41 meses
#
#       Moradores que Alimentaram Acabamento (Sim)  \
# 62                                           Não
# 82                                           Não
# 92                                           Sim
# 93                                           Sim
# 111                                          Não
# ...                                          ...
# 14492                                        Não
# 14523                                        Não
# 14530                                        Sim
# 14551                                        Sim
# 14552                                        Não
#
#       Moradores que Alimentaram Acabamento (Não) Tipo de Domicílio  \
# 62                                           Não              Casa
# 82                                           Não              Casa
# 92                                           Não              Casa
# 93                                           Não              Casa
# 111                                          Não       Apartamento
# ...                                          ...               ...
# 14492                                        Não              Casa
# 14523                                        Não              Casa
# 14530                                        Não              Casa
# 14551                                        Não              Casa
# 14552                                        Não              Casa
#
#       Possui Cozinha                            Ocupação  ... n02_legumes  \
# 62               Sim                             Alugado  ...           4
# 82               Sim               Cedido de outra forma  ...           3
# 92               Sim                             Alugado  ...           3
# 93               Sim               Cedido de outra forma  ...           4
# 111              Sim  Próprio de algum morador - já pago  ...           4
# ...              ...                                 ...  ...         ...
# 14492            Sim                             Alugado  ...           4
# 14523            Sim                             Alugado  ...           4
# 14530            Sim  Próprio de algum morador - já pago  ...           4
# 14551            Sim                             Alugado  ...           4
# 14552            Sim  Próprio de algum morador - já pago  ...           2
#
#       n03_verduras n04_feijao n05_suco      peso_crianca  h12_alergias  \
# 62               4          4        3  4075,16113823172     A
# 82               3          3        3  1932,89060519619     A
# 92               1          4        0  2249,89827350044     A
# 93               3          4        0  2249,89827350044     AD
# 111              2          4        1   1767,7772148932     AH
# ...            ...        ...      ...               ...           ...
# 14492            4          4        0  251,519047619048     H
# 14523            4          4        1  169,753846153846     F
# 14530            2          4        4             367,8     AB
# 14551            4          4        4  359,535714285714     E
# 14552            3          4        3  359,535714285714     F
#
#        h121_alergia_leite  h122_alergia_ovos  h126_alergia_frutas  \
# 62                    Sim                Não                  Não
# 82                    Sim                Não                  Não
# 92                    Sim                Não                  Não
# 93                    Sim                Não                  Não
# 111                   Sim                Não                  Não
# ...                   ...                ...                  ...
# 14492                 Não                Não                  Não
# 14523                 Não                Não                  Sim
# 14530                 Sim                Sim                  Não
# 14551                 Não                Não                  Não
# 14552                 Não                Não                  Sim
#
#       k29_alimentacao
# 62                Não
# 82      Mais ou menos
# 92              Muito
# 93              Muito
# 111     Mais ou menos
# ...               ...
# 14492           Muito
# 14523           Muito
# 14530           Muito
# 14551   Mais ou menos
# 14552           Pouco
#
# [529 rows x 25 columns]

# %%
# Exibir o novo dataset
novo_dataset.head(5)
# Out:
#   a00_regiao   b02_sexo  b04_idade  b05_data b05a_idade_em_meses  \
# 0      Norte  Masculino          1  11092017            22 meses
# 1      Norte   Feminino          4   6042015            51 meses
# 2      Norte   Feminino          2  21122016            30 meses
# 3      Norte  Masculino          4  13112014            56 meses
# 4      Norte   Feminino          0   2092018            10 meses
#
#   l01_morador_alim_acabassem l02_morador_alim_acabaram p02_tipo_de_domicilio  \
# 0                        Sim                       Não           Apartamento
# 1                        Sim                       Não           Apartamento
# 2                        Sim                       Sim                  Casa
# 3                        Sim                       Sim                  Casa
# 4                        Sim                       Não                  Casa
#
#   p06_cozinha                        p03_ocupacao  ... n02_legumes  \
# 0         Sim               Cedido de outra forma  ...           0
# 1         Sim               Cedido de outra forma  ...           0
# 2         Sim               Cedido de outra forma  ...           0
# 3         Sim               Cedido de outra forma  ...           0
# 4         Não  Próprio de algum morador - já pago  ...           2
#
#   n03_verduras n04_feijao n05_suco      peso_crianca  h12_alergias  \
# 0            0          4        2  859,598538120578
# 1            0          4        2  859,598538120578
# 2            0          4        1  859,598538120578
# 3            0          4        1  859,598538120578
# 4            2          4        2  859,598538120578
#
#    h121_alergia_leite  h122_alergia_ovos  h126_alergia_frutas k29_alimentacao
# 0                 NaN                NaN                  NaN             Não
# 1                 NaN                NaN                  NaN             NaN
# 2                 NaN                NaN                  NaN             Não
# 3                 NaN                NaN                  NaN             NaN
# 4                 NaN                NaN                  NaN           Pouco
#
# [5 rows x 25 columns]

# %% [markdown]
# ## LEGENDAS
#
# *Região* = Macrorregião
#
# *Sexo* = Sexo da criança
#
# *Idade* = Idade em anos completos da criança
#
# *Data de Nascimento* = Data de nascimento da criança
#
# *Idade em Meses* = Idade em meses da criança
#
# *Moradores que Alimentaram Acabamento (Sim)* = Os moradores tiveram a preocupação de que os alimentos acabassem antes de poderem comprar ou receber mais comida
#
# *Moradores que Alimentaram Acabamento (Não)* = Os alimentos acabaram antes que os moradores tivessem dinheiro para comprar mais comida
#
# *Tipo de Domicílio* = Tipo de domicílio
#
# *Possui Cozinha* = O domicílio tem cozinha
#
# *Ocupação* = Tipo de ocupação do domicílio
#
# *Situação do Registro* = Situação do setor do domicílio
#
# *Presença de Tosse* = A criança está ou esteve com tosse nos últimos 15 dias
#
# *Tipo de Respiração* = A criança está ou esteve com respiração difícil nos últimos 15 dias
#
# *Alimentos Básicos* = Quando cozinha em casa, você utiliza principalmente alimentos básicos, por exemplo: arroz, feijão, legumes, verduras, carnes, ovos, temperos naturais?

# %%
# Dicionário para renomear as colunas
novos_nomes = {
    'a00_regiao': 'Região',
    'b02_sexo': 'Sexo',
    'b04_idade': 'Idade',
    'b05_data': 'Data de Nascimento',
    'b05a_idade_em_meses': 'Idade em Meses',
    'l01_morador_alim_acabassem': 'Moradores que Alimentaram Acabamento (Sim)',
    'l02_morador_alim_acabaram': 'Moradores que Alimentaram Acabamento (Não)',
    'p02_tipo_de_domicilio': 'Tipo de Domicílio',
    'p06_cozinha': 'Possui Cozinha',
    'p03_ocupacao': 'Ocupação',
    'a11_situacao': 'Situação do Registro',
    'h14_tosse': 'Presença de Tosse',
    'h15_respiracao': 'Tipo de Respiração',
    'm03_alimentos_basicos': 'Alimentos Básicos'
}

# Renomeando as colunas
novo_dataset.rename(columns=novos_nomes, inplace=True)

# Salvar o dataset filtrado em um novo arquivo CSV
novo_dataset.to_csv("[2]Dataset_limpo.csv", index=False)

# Exibindo o DataFrame com os novos nomes
novo_dataset.head(5)
# Out:
# <ipython-input-21-ba0490630a53>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   novo_dataset.rename(columns=novos_nomes, inplace=True)
#   Região       Sexo  Idade  Data de Nascimento Idade em Meses  \
# 0  Norte  Masculino      1            11092017       22 meses
# 1  Norte   Feminino      4             6042015       51 meses
# 2  Norte   Feminino      2            21122016       30 meses
# 3  Norte  Masculino      4            13112014       56 meses
# 4  Norte   Feminino      0             2092018       10 meses
#
#   Moradores que Alimentaram Acabamento (Sim)  \
# 0                                        Sim
# 1                                        Sim
# 2                                        Sim
# 3                                        Sim
# 4                                        Sim
#
#   Moradores que Alimentaram Acabamento (Não) Tipo de Domicílio Possui Cozinha  \
# 0                                        Não       Apartamento            Sim
# 1                                        Não       Apartamento            Sim
# 2                                        Sim              Casa            Sim
# 3                                        Sim              Casa            Sim
# 4                                        Não              Casa            Não
#
#                              Ocupação  ... n02_legumes n03_verduras  \
# 0               Cedido de outra forma  ...           0            0
# 1               Cedido de outra forma  ...           0            0
# 2               Cedido de outra forma  ...           0            0
# 3               Cedido de outra forma  ...           0            0
# 4  Próprio de algum morador - já pago  ...           2            2
#
#   n04_feijao n05_suco      peso_crianca  h12_alergias  h121_alergia_leite  \
# 0          4        2  859,598538120578                               NaN
# 1          4        2  859,598538120578                               NaN
# 2          4        1  859,598538120578                               NaN
# 3          4        1  859,598538120578                               NaN
# 4          4        2  859,598538120578                               NaN
#
#    h122_alergia_ovos  h126_alergia_frutas k29_alimentacao
# 0                NaN                  NaN             Não
# 1                NaN                  NaN             NaN
# 2                NaN                  NaN             Não
# 3                NaN                  NaN             NaN
# 4                NaN                  NaN           Pouco
#
# [5 rows x 25 columns]

# %%
data = novo_dataset.copy()

# %% [markdown]
# ### **04. Análise Descritiva.**

# %% [markdown]
# ### 04.1 - Identificar padrões de introdução alimentar e o consumo de alimentos específicos por idade

# %% [markdown]
# ##### 04.1 -

# %%
data['n01_frutas']
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 14553    4
# 14554    4
# 14555    4
# 14556    4
# 14557    4
# Name: n01_frutas, Length: 14558, dtype: int64

# %% [markdown]
# ### A maioria das colunas possui valores categóricos, que podem ser analisados por meio de contagens e distribuições.

# %% [markdown]
# ### **05. Análise Exploratória de Dados.**

# %%
# 1. Medidas de Tendência Central - Idade
media_idade = data['Idade'].mean()
mediana_idade = data['Idade'].median()

# %%
# Gráficos
# 1. Histograma da Idade
plt.figure(figsize=(8, 6))
data['Idade'].plot(kind='hist', bins=20, alpha=0.7, edgecolor='black')
plt.title('Distribuição da Idade')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# 2. Medidas de Dispersão - Idade
desvio_padrao_idade = data['Idade'].std()
amplitude_idade = data['Idade'].max() - data['Idade'].min()

# %%
# 2. Gráfico de Barras para Proporção de Gênero
plt.figure(figsize=(6, 6))
data['Sexo'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, explode=(0.05, 0))
plt.title('Proporção de Gênero')
plt.ylabel('')
plt.show()

# %%
# 3. Medidas de Contagem e Proporção
frequencia_genero = data['Sexo'].value_counts()
percentual_genero = data['Sexo'].value_counts(normalize=True) * 100

# %%
# 3. Boxplot da Idade
plt.figure(figsize=(8, 6))
sns.boxplot(x=data['Idade'], color='lightblue')
plt.title('Boxplot da Idade')
plt.xlabel('Idade')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# 4. Gráfico de Barras para Presença de Tosse
plt.figure(figsize=(8, 6))
data['Presença de Tosse'].value_counts().plot(kind='bar', color='lightcoral', edgecolor='black')
plt.title('Frequência de Presença de Tosse')
plt.xlabel('Presença de Tosse')
plt.ylabel('Frequência')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# 5. Frequência de Tipo de Domicílio e Presença de Tosse
frequencia_domicilio = data['Tipo de Domicílio'].value_counts()
frequencia_tosse = data['Presença de Tosse'].value_counts()

# %%
# 5. Gráfico de Barras para Tipo de Domicílio
plt.figure(figsize=(8, 6))
data['Tipo de Domicílio'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Proporção por Tipo de Domicílio')
plt.xlabel('Tipo de Domicílio')
plt.ylabel('Frequência')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Gráfico 6: Distribuição de Crianças por Região Geográfica
plt.figure(figsize=(10, 6))
sns.countplot(x='a00_regiao', data=dataset)
plt.title('Distribuição de Crianças por Região Geográfica')
plt.xlabel('Região Geográfica')
plt.ylabel('Número de Crianças')
plt.show()

# %% [markdown]
# ## <font color=green size=6>**Esclarecimentos e Requisitos do projeto**</font>
#
# 1. Este projeto precisa começar pela definição de um tema. Por exemplo: arboviroses no Brasil.
#
#
# 2. A partir do tema, a equipe deve identificar um banco de dados ou dataset, preferencialmente, utilizando dados reais.
#
#
# 3. Com base na relação entre o tema e os dados identificados, a equipe deve identificar um problema a ser solucionado. Por exemplo: identificar as principais condutas das pessoas que podem prevenir a piora de um quadro de arbovirose. É preciso que esse problema seja passível de solução por meio do banco de dados escolhido pela equipe.
#
#
# 4. A equipe deve pré-processar o banco de dados identificado.
# - 4.1. Provavelmente, nem todas as colunas (variáveis / features) presentes no banco serão necessárias para a solução do problema que a equipe escolheu para lidar.
# - 4.2 Da mesma forma, nem todas as linhas do banco (relacionadas a dados como os de participantes de uma pesquisa) podem ser necessárias. Por exemplo: algumas linhas podem ter muitos dados nulos, que pode ser útil simplesmente excluir. Outro exemplo: o estudo que a equipe escolheu envolve apenas a saúde da mulher, permitindo a exclusão dos dados dos homens.
# - 4.3. Por fim, é possível que existam dados inconsistentes e que precisam ser corrigidos ou dados com texto e que devem ser transformados em números, se o que se espera é que sejam processados estatisticamente.
#
#
# 5. Com o banco de dados em condições de processamento, é necessário conduzir uma Análise Exploratória de Dados. Isso significa utilizar bibliotecas do python que permitiu calcular estatísticas descritivas.
# - 5.1. Considere as seguintes estatísticas: medidas de tendência central (ex.: média), medidas de dispersão (ex.: desvio-padrão), medidas de contagem e proporção (ex.: frequência, percentual), medidas de associação (ex.: correlação de pearson).
# - 5.2. Considere os seguintes gráficos: histograma, gráfico de barras, boxplot.
# - 5.3. Você deve apresentar neste notebook 05 estatísticas descritivas e 05 gráficos relacionados ao banco de dados pré-processado e que ajudem a caracterizar os seus dados, te aproximando da solução do problema que a equipe selecionou.
#
#
# 6. Esta entrega deve ocorrer até o dia 12/12/2024.
#
# *A título de informação, lembramos que a 2ª entrega deste projeto será um modelo de IA, que ajude a solucionar o problema que a equipe escolheu e a última entrega será um dashboard unindo as estatísticas da 1ª entrega com o modelo da 2ª entrega.*
